# %%
tested_qubits = {('1', '2'),
 ('13', '14'),
 ('15', '23'),
 ('16', '17'),
 ('19', '27'),
 ('20', '28'),
 ('21', '22'),
 ('24', '32'),
 ('25', '26'),
 ('29', '30'),
 ('3', '4'),
 ('33', '34'),
 ('35', '43'),
 ('36', '44'),
 ('37', '45'),
 ('38', '39'),
 ('41', '47'),
 ('48', '52'),
 ('5', '11'),
 ('50', '51'),
 ('53', '54'),
 ('6', '12'),
 ('9', '10')}

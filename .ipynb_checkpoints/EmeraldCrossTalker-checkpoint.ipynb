# %%
tested_qubits = {('1', '2'),
 ('14', '22'),
 ('15', '23'),
 ('17', '18'),
 ('19', '27'),
 ('20', '28'),
 ('21', '29'),
 ('24', '32'),
 ('25', '33'),
 ('26', '34'),
 ('3', '4'),
 ('30', '31'),
 ('35', '43'),
 ('36', '44'),
 ('37', '45'),
 ('38', '39'),
 ('41', '47'),
 ('48', '52'),
 ('49', '53'),
 ('5', '11'),
 ('50', '54'),
 ('6', '12'),
 ('8', '16'),
 ('9', '10')}

# %%
import networkx as nx
from braket.aws import AwsDevice
from braket.circuits import Circuit
from braket.devices import Devices
import matplotlib.pyplot as plt
from math import pi

Emerald_device = AwsDevice("arn:aws:braket:eu-north-1::device/qpu/iqm/Emerald")
G = Emerald_device.topology_graph
nx.draw_kamada_kawai(G, with_labels=True, node_color = 'black' ,font_color="white", arrows=False)
plt.show()

total_connectivity = Emerald_device.properties.paradigm.connectivity.connectivityGraph
qubits = [qub for qub in total_connectivity]
qubits.sort(key=float)

red_edges = list(tested_qubits)
connected_qubits = [str(qub_pair[0]) for qub_pair in red_edges] + [str(qub_pair[1]) for qub_pair in red_edges]
connected_qubits.sort(key=float)
# print("Connected Qubits:\n",connected_qubits,"\n")
# print("Total Qubits:\n",qubits,"\n")
print("Efficiency:", len(connected_qubits)/len(qubits))

# 3. Create a color map based on G.edges()
edge_colors = []
widths = []
for u, v in G.edges():
    u = str(u)
    v = str(v)
    # Check if the edge (or its reverse) is in your red_subset
    if (u, v) in red_edges or (v, u) in red_edges:
        edge_colors.append('red')
        widths.append(6)
    else:
        edge_colors.append('black')
        widths.append(3)

black_edges = [e for e in G.edges() if e not in red_edges and (e[1], e[0]) not in red_edges]

nx.draw_kamada_kawai(G, with_labels=True, edge_color=edge_colors, node_color = 'black' ,font_color="white", width = widths, arrows=False)
plt.show()
# Out:
# Efficiency: 0.9056603773584906

# %%
chosen_qubits = [1,2,5,6,7,11,12,13,14,19,20,21,22,27,28,29,30,31,35,36,37,38,39,44,45,50,51,54]

# %%
cross_talked_qubits = set()

for q_0,q_1 in tested_qubits:
    if (int(q_0) in chosen_qubits) and (int(q_1) in chosen_qubits):
        cross_talked_qubits.add((q_0,q_1))


cross_talked_qubits
# Out:
# {('1', '2'),
#  ('14', '22'),
#  ('19', '27'),
#  ('20', '28'),
#  ('21', '29'),
#  ('30', '31'),
#  ('36', '44'),
#  ('37', '45'),
#  ('38', '39'),
#  ('5', '11'),
#  ('50', '54'),
#  ('6', '12')}

# %%
Full_Emerald_Bell_state = Circuit()
for q_0,q_1 in tested_qubits:
    q_l_int = int(min(q_0,q_1))
    q_b_int = int(max(q_0,q_1))
    Full_Emerald_Bell_state = Full_Emerald_Bell_state.h(q_l_int).cnot(q_l_int, q_b_int)

Half_Emerald_Bell_state = Circuit()
for q_0,q_1 in cross_talked_qubits:
    q_l_int = int(min(q_0,q_1))
    q_b_int = int(max(q_0,q_1))
    Half_Emerald_Bell_state = Half_Emerald_Bell_state.h(q_l_int).cnot(q_l_int, q_b_int)

# %%
Full_Emerald_Bell_task = Emerald_device.run(Full_Emerald_Bell_state, shots=4096, disable_qubit_rewiring=True)

# %%
Half_Emerald_Bell_task = Emerald_device.run(Half_Emerald_Bell_state, shots=4096, disable_qubit_rewiring=True)

# %%
Full_Emerald_Bell_result = Full_Emerald_Bell_task.result()
Half_Emerald_Bell_result = Half_Emerald_Bell_task.result()

# %%
print(Full_Emerald_Bell_result.measured_qubits)
# Out:
# [21, 29, 15, 23, 30, 31, 25, 33, 17, 18, 19, 27, 37, 45, 10, 9, 14, 22, 38, 39, 1, 2, 16, 8, 12, 6, 11, 5, 49, 53, 26, 34, 35, 43, 24, 32, 50, 54, 36, 44, 48, 52, 3, 4, 41, 47, 20, 28]

# %%
print(Half_Emerald_Bell_result.measured_qubits)
# Out:
# [21, 29, 30, 31, 37, 45, 19, 27, 14, 22, 50, 54, 20, 28, 1, 2, 36, 44, 12, 6, 38, 39, 11, 5]

# %%
import json
Full_Emerald_state_bitstrings = Full_Emerald_Bell_result.measurement_counts.keys()

print(Full_Emerald_Bell_result.measured_qubits)

with open('/home/ec2-user/SageMaker/Full_Emerald_Bell_result.json', 'w', encoding='utf-8') as f:
    json.dump(str(Full_Emerald_state_bitstrings), f, ensure_ascii=False, indent=4)
# Out:
# [21, 29, 15, 23, 30, 31, 25, 33, 17, 18, 19, 27, 37, 45, 10, 9, 14, 22, 38, 39, 1, 2, 16, 8, 12, 6, 11, 5, 49, 53, 26, 34, 35, 43, 24, 32, 50, 54, 36, 44, 48, 52, 3, 4, 41, 47, 20, 28]

# %%
import json
Half_Emerald_state_bitstrings = Half_Emerald_Bell_result.measurement_counts.keys()

print(Half_Emerald_Bell_result.measured_qubits)

with open('/home/ec2-user/SageMaker/Half_Emerald_Bell_result.json', 'w', encoding='utf-8') as f:
    json.dump(str(Half_Emerald_state_bitstrings), f, ensure_ascii=False, indent=4)
